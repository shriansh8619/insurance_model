# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\saksh\OneDrive\Desktop\carInsurance_data.csv")

# %%
df.head()
# Out:
#    Id  Age          Job  Marital Education  Default  Balance  HHInsurance  \
# 0   1   32   management   single  tertiary        0     1218            1
# 1   2   32  blue-collar  married   primary        0     1156            1
# 2   3   29   management   single  tertiary        0      637            1
# 3   4   25      student   single   primary        0      373            1
# 4   5   30   management  married  tertiary        0     2694            0
#
#    CarLoan Communication  LastContactDay LastContactMonth  NoOfContacts  \
# 0        0     telephone              28              jan             2
# 1        0           NaN              26              may             5
# 2        0      cellular               3              jun             1
# 3        0      cellular              11              may             2
# 4        0      cellular               3              jun             1
#
#    DaysPassed  PrevAttempts  Outcome CallStart   CallEnd  CarInsurance
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id                4000 non-null   int64
#  1   Age               4000 non-null   int64
#  2   Job               3981 non-null   object
#  3   Marital           4000 non-null   object
#  4   Education         3831 non-null   object
#  5   Default           4000 non-null   int64
#  6   Balance           4000 non-null   int64
#  7   HHInsurance       4000 non-null   int64
#  8   CarLoan           4000 non-null   int64
#  9   Communication     3098 non-null   object
#  10  LastContactDay    4000 non-null   int64
#  11  LastContactMonth  4000 non-null   object
#  12  NoOfContacts      4000 non-null   int64
#  13  DaysPassed        4000 non-null   int64
#  14  PrevAttempts      4000 non-null   int64
#  15  Outcome           958 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# Id                     0
# Age                    0
# Job                   19
# Marital                0
# Education            169
# Default                0
# Balance                0
# HHInsurance            0
# CarLoan                0
# Communication        902
# LastContactDay         0
# LastContactMonth       0
# NoOfContacts           0
# DaysPassed             0
# PrevAttempts           0
# Outcome             3042
# CallStart              0
# CallEnd                0
# CarInsurance           0
# dtype: int64

# %%
df["Communication"].value_counts()
# Out:
# Communication
# cellular     2831
# telephone     267
# Name: count, dtype: int64

# %%
df["Outcome"].value_counts()
# Out:
# Outcome
# failure    437
# success    326
# other      195
# Name: count, dtype: int64

# %%
df["Job"].value_counts()
# Out:
# Job
# management       893
# blue-collar      759
# technician       660
# admin.           459
# services         330
# retired          249
# self-employed    140
# student          131
# unemployed       130
# entrepreneur     121
# housemaid        109
# Name: count, dtype: int64

# %%
df["Education"].value_counts()
# Out:
# Education
# secondary    1988
# tertiary     1282
# primary       561
# Name: count, dtype: int64

# %%
df.drop(columns = ["CallStart","CallEnd","Id"], inplace = True , axis = 1)

# %%
df.head()
# Out:
#    Age          Job  Marital Education  Default  Balance  HHInsurance  \
# 0   32   management   single  tertiary        0     1218            1
# 1   32  blue-collar  married   primary        0     1156            1
# 2   29   management   single  tertiary        0      637            1
# 3   25      student   single   primary        0      373            1
# 4   30   management  married  tertiary        0     2694            0
#
#    CarLoan Communication  LastContactDay LastContactMonth  NoOfContacts  \
# 0        0     telephone              28              jan             2
# 1        0           NaN              26              may             5
# 2        0      cellular               3              jun             1
# 3        0      cellular              11              may             2
# 4        0      cellular               3              jun             1
#
#    DaysPassed  PrevAttempts  Outcome  CarInsurance
# 0          -1             0      NaN             0
# ...

# %%
df["DaysPassed"] = np.abs(df["DaysPassed"])

# %%
df.drop(columns = "Outcome" , inplace = True , axis = 1)

# %%
df.drop(columns = "Communication", inplace = True , axis = 1)

# %%
df.isnull().sum()
# Out:
# Age                   0
# Job                  19
# Marital               0
# Education           169
# Default               0
# Balance               0
# HHInsurance           0
# CarLoan               0
# LastContactDay        0
# LastContactMonth      0
# NoOfContacts          0
# DaysPassed            0
# PrevAttempts          0
# CarInsurance          0
# dtype: int64

# %%
df["Education"] = df["Education"].fillna(df["Education"].mode()[0])

# %%
df.isnull().sum()
# Out:
# Age                  0
# Job                 19
# Marital              0
# Education            0
# Default              0
# Balance              0
# HHInsurance          0
# CarLoan              0
# LastContactDay       0
# LastContactMonth     0
# NoOfContacts         0
# DaysPassed           0
# PrevAttempts         0
# CarInsurance         0
# dtype: int64

# %%
df.dropna(subset = "Job", axis = 0 , inplace = True)

# %%
df.isnull().sum()
# Out:
# Age                 0
# Job                 0
# Marital             0
# Education           0
# Default             0
# Balance             0
# HHInsurance         0
# CarLoan             0
# LastContactDay      0
# LastContactMonth    0
# NoOfContacts        0
# DaysPassed          0
# PrevAttempts        0
# CarInsurance        0
# dtype: int64

# %%
df.shape
# Out:
# (3981, 14)

# %%
df["Default"].value_counts()
# Out:
# Default
# 0    3923
# 1      58
# Name: count, dtype: int64

# %%
df.drop(columns = "Default" , axis = 1, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3981 entries, 0 to 3999
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               3981 non-null   int64
#  1   Job               3981 non-null   object
#  2   Marital           3981 non-null   object
#  3   Education         3981 non-null   object
#  4   Balance           3981 non-null   int64
#  5   HHInsurance       3981 non-null   int64
#  6   CarLoan           3981 non-null   int64
#  7   LastContactDay    3981 non-null   int64
#  8   LastContactMonth  3981 non-null   object
#  9   NoOfContacts      3981 non-null   int64
#  10  DaysPassed        3981 non-null   int64
#  11  PrevAttempts      3981 non-null   int64
#  12  CarInsurance      3981 non-null   int64
# dtypes: int64(9), object(4)
# memory usage: 435.4+ KB

# %%
df.head(2)
# Out:
#    Age          Job  Marital Education  Balance  HHInsurance  CarLoan  \
# 0   32   management   single  tertiary     1218            1        0
# 1   32  blue-collar  married   primary     1156            1        0
#
#    LastContactDay LastContactMonth  NoOfContacts  DaysPassed  PrevAttempts  \
# 0              28              jan             2           1             0
# 1              26              may             5           1             0
#
#    CarInsurance
# 0             0
# 1             0

# %%
df["CarInsurance"].value_counts()
# Out:
# CarInsurance
# 0    2386
# 1    1595
# Name: count, dtype: int64

# %%
df["HHInsurance"].value_counts()
# Out:
# HHInsurance
# 0    2012
# 1    1969
# Name: count, dtype: int64

# %%
df["CarLoan"].value_counts()
# Out:
# CarLoan
# 0    3450
# 1     531
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df1 = df.apply(lambda x : le.fit_transform(x) if x.dtype == "object" else x)

# %%
df1
# Out:
#       Age  Job  Marital  Education  Balance  HHInsurance  CarLoan  \
# 0      32    4        2          2     1218            1        0
# 1      32    1        1          0     1156            1        0
# 2      29    4        2          2      637            1        0
# 3      25    8        2          0      373            1        0
# 4      30    4        1          2     2694            0        0
# ...   ...  ...      ...        ...      ...          ...      ...
# 3995   28    9        2          2        0            1        0
# 3996   49    0        0          1      124            1        1
# 3997   27    0        2          1     -400            0        1
# 3998   36    2        2          2      658            1        0
# 3999   45    7        1          0      137            1        0
#
#       LastContactDay  LastContactMonth  NoOfContacts  DaysPassed  \
# 0                 28                 4             2           1
# ...

# %%
corr = df1.corr()

# %%
sns.heatmap(corr , annot = True , fmt = "1.1f")
plt.show()

# %%
corr["CarInsurance"]
# Out:
# Age                 0.038944
# Job                 0.077077
# Marital             0.047522
# Education           0.091099
# Balance             0.041397
# HHInsurance        -0.202887
# CarLoan            -0.091589
# LastContactDay     -0.062461
# LastContactMonth   -0.013071
# NoOfContacts       -0.114162
# DaysPassed          0.135882
# PrevAttempts        0.147548
# CarInsurance        1.000000
# Name: CarInsurance, dtype: float64

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.metrics import classification_report

# %%
x = df1.drop(columns = "CarInsurance", axis = 1)
y = df1["CarInsurance"]

# %%
x_train , x_test, y_train, y_test = train_test_split( x,y , test_size = 0.3 , random_state = 42 )

# %%
rfc = RandomForestClassifier()

# %%
rfc.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_train_pred = rfc.predict(x_train)

# %%
print(classification_report(y_train , y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1656
#            1       1.00      1.00      1.00      1130
#
#     accuracy                           1.00      2786
#    macro avg       1.00      1.00      1.00      2786
# weighted avg       1.00      1.00      1.00      2786

# %%
y_test_pred = rfc.predict(x_test)

# %%
print(classification_report(y_test , y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.85      0.78       730
#            1       0.68      0.50      0.57       465
#
#     accuracy                           0.71      1195
#    macro avg       0.70      0.67      0.68      1195
# weighted avg       0.71      0.71      0.70      1195

# %%
rfc.feature_importances_
# Out:
# array([0.16828457, 0.08059693, 0.03932814, 0.03744678, 0.18191704,
#        0.04559996, 0.01888406, 0.13757127, 0.11458798, 0.07292941,
#        0.06884494, 0.03400892])

# %%
plt.figure( figsize = (15,5))
sns.barplot(x = x_train.columns , y = rfc.feature_importances_ )
plt.xticks(rotation = 45)
plt.show()

# %%
fi = pd.DataFrame({"Col_names": x_train.columns, "importance":rfc.feature_importances_})
fi.sort_values(by = "importance", ascending = False)
# Out:
#            Col_names  importance
# 4            Balance    0.181917
# 0                Age    0.168285
# 7     LastContactDay    0.137571
# 8   LastContactMonth    0.114588
# 1                Job    0.080597
# 9       NoOfContacts    0.072929
# 10        DaysPassed    0.068845
# 5        HHInsurance    0.045600
# 2            Marital    0.039328
# 3          Education    0.037447
# 11      PrevAttempts    0.034009
# 6            CarLoan    0.018884

# %%
cat = df.select_dtypes(include = "object")
cat.columns
# Out:
# Index(['Job', 'Marital', 'Education', 'LastContactMonth'], dtype='object')

# %%
c = ['Job', 'Marital', 'Education', 'LastContactMonth']

# %%
for i in c:
    print(i)
    print()
    print(df[i].value_counts())
# Out:
# Job
#
# Job
# management       893
# blue-collar      759
# technician       660
# admin.           459
# services         330
# retired          249
# self-employed    140
# student          131
# unemployed       130
# entrepreneur     121
# housemaid        109
# Name: count, dtype: int64
# Marital
#
# Marital
# married     2295
# single      1205
# divorced     481
# Name: count, dtype: int64
# Education
#
# Education
# secondary    2144
# tertiary     1280
# primary       557
# Name: count, dtype: int64
# LastContactMonth
#
# LastContactMonth
# may    1048
# jul     570
# aug     533
# jun     451
# nov     346
# apr     304
# feb     261
# jan     132
# oct     115
# sep     101
# mar      79
# dec      41
# Name: count, dtype: int64

# %%
e = ['Job', 'Marital', 'Education', 'LastContactMonth']

for i in e:
    print(i)
    print()
    print(x[i].value_counts())
# Out:
# Job
#
# Job
# 4     893
# 1     759
# 9     660
# 0     459
# 7     330
# 5     249
# 6     140
# 8     131
# 10    130
# 2     121
# 3     109
# Name: count, dtype: int64
# Marital
#
# Marital
# 1    2295
# 2    1205
# 0     481
# Name: count, dtype: int64
# Education
#
# Education
# 1    2144
# 2    1280
# 0     557
# Name: count, dtype: int64
# LastContactMonth
#
# LastContactMonth
# 8     1048
# 5      570
# 1      533
# 6      451
# 9      346
# 0      304
# 3      261
# 4      132
# 10     115
# 11     101
# 7       79
# 2       41
# Name: count, dtype: int64

# %%
df
# Out:
#       Age           Job   Marital  Education  Balance  HHInsurance  CarLoan  \
# 0      32    management    single   tertiary     1218            1        0
# 1      32   blue-collar   married    primary     1156            1        0
# 2      29    management    single   tertiary      637            1        0
# 3      25       student    single    primary      373            1        0
# 4      30    management   married   tertiary     2694            0        0
# ...   ...           ...       ...        ...      ...          ...      ...
# 3995   28    technician    single   tertiary        0            1        0
# 3996   49        admin.  divorced  secondary      124            1        1
# 3997   27        admin.    single  secondary     -400            0        1
# 3998   36  entrepreneur    single   tertiary      658            1        0
# 3999   45      services   married    primary      137            1        0
#
# ...

# %%
import pickle

# %%
with open("build.pkl", "wb") as file:
    pickle.dump(rfc, file)

# %%
cat.columns
# Out:
# Index(['Job', 'Marital', 'Education', 'LastContactMonth'], dtype='object')

# %%
x.columns
# Out:
# Index(['Age', 'Job', 'Marital', 'Education', 'Balance', 'HHInsurance',
#        'CarLoan', 'LastContactDay', 'LastContactMonth', 'NoOfContacts',
#        'DaysPassed', 'PrevAttempts'],
#       dtype='object')
